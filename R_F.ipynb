# %%
! cd ./drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Random_Forests/data.csv")

# %%
# !pwd
# Out:
# /content

# %%
! mv /content/drive/MyDrive/Colab_Notebooks/R_F.ipynb /content/drive/MyDrive/Random_Forests

# %%
df = pd.read_csv("/content/drive/MyDrive/Random_Forests/data.csv")

# %%
df_filtered = df.dropna(axis=0)
# df = df.interpolate('linear')
# df
df_filtered
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    2
# ...

# %%
mv /content/modified.csv /content/drive/MyDrive/Random_Forests

# %%
X = df_filtered.iloc[ : , : -1]
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal
# 0        3  0.0   6.0
# 1        2  3.0   3.0
# ...

# %%
y = df_filtered.iloc[ : ,-1:]
y
# Out:
#      num
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
# ..   ...
# 298    1
# 299    2
# 300    3
# 301    1
# 302    0
#
# [303 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
classifier = RandomForestClassifier(n_estimators = 100)
classifier.fit(X_train,y_train)
# Out:
# <ipython-input-89-6757d9884ee7>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(X_train,y_train)
# RandomForestClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL: 0.5164835164835165
